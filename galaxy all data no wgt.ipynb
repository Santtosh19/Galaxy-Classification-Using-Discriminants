# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,confusion_matrix

#This is where we put our csv file from the directory of 'bnnz/output/test_singleCls_quick/clasif/eval/ANNZ_singleCls_0000.csv'
#In this case i'm using jupyter notebook, so i will import the csv file into the same file where im doing this notebook
# Load your CSV file
file_path = 'annh2_all_nowgt.csv'
data = pd.read_csv(file_path)

predicted = data['F :ANNZ_0']
#1:rounded and 0:no bulge
data['type'] = data['type'].replace({1: 1, 3: 0})
true_labels = data['type']
threshold = 0.5
binary_predictions = (predicted >= threshold).astype(int)

accuracy = accuracy_score(true_labels, binary_predictions)
precision = precision_score(true_labels, binary_predictions)
recall = recall_score(true_labels, binary_predictions)
f1_score = f1_score(true_labels, binary_predictions)
confusion_matrix=confusion_matrix(true_labels,binary_predictions)

print("Model Metrics:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"Confusion_Matrix:\n{confusion_matrix}")

#Statistics Calculation
from sklearn.metrics import confusion_matrix, mean_absolute_error
import numpy as np
tn, fp, fn, tp = confusion_matrix(true_labels,binary_predictions).ravel() #ravel() is something like .items() but this one is for dictionary : key,value
# ravel() makes it into 1d array and we can unpack
errors = [fp, fn]
positive=[tn,tp]
# Standard deviation 
std_dev = np.std(errors)
std_dev_p=np.std(positive)
# Mean absolute error
mae = mean_absolute_error(true_labels, binary_predictions)

print (f"tn:{tn}")
print(f"fp:{fp}")
print(f"fn:{fn}")
print(f"tp:{tp}")
print(f"Standard Deviation of Errors: {std_dev}")
print(f"Standard Deviation of Positives: {std_dev_p}")
print(f"Mean Absolute Error: {mae}")


#####################VISUALIZATION
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(8,8))
sns.kdeplot(data[true_labels == 1]['F :ANNZ_0'], color='blue', label='Rounded Galaxy (Class 1)', lw=3)##lw is line width
sns.kdeplot(data[true_labels == 0]['F :ANNZ_0'], color='red', label='No Bulge Galaxy (Class 0)', lw=3)
plt.axvline(x=0.5, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title(f'Distribution of Predictions using Gaussian KDE')
plt.xlabel('Predictions')
plt.ylabel('Density')
plt.legend()
plt.show()


#########OUTLINES
plt.figure(figsize=(8, 8))
plt.scatter(data.index[true_labels == 1], predicted[true_labels == 1], c='blue', alpha=0.5, s=25, linewidth=0.5, label='Rounded Galaxy : 1')
plt.scatter(data.index[true_labels == 0], predicted[true_labels == 0], c='red', alpha=0.5, s=25, linewidth=0.5, label='No Bulge Galaxy : 0')
plt.axhline(y=threshold, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title('Scatter Plot of Predicted Data Points')
plt.xlabel('Data Points Index')
plt.ylabel('Predictions')
plt.legend()
plt.show()
# Out:
# Model Metrics:
# Accuracy: 0.9052287581699346
# Precision: 0.9555555555555556
# Recall: 0.9188034188034188
# F1 Score: 0.9368191721132898
# Confusion_Matrix:
# [[ 62  10]
#  [ 19 215]]
# tn:62
# fp:10
# fn:19
# tp:215
# Standard Deviation of Errors: 4.5
# Standard Deviation of Positives: 76.5
# Mean Absolute Error: 0.09477124183006536

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,confusion_matrix

#This is where we put our csv file from the directory of 'bnnz/output/test_singleCls_quick/clasif/eval/ANNZ_singleCls_0000.csv'
#In this case i'm using jupyter notebook, so i will import the csv file into the same file where im doing this notebook
# Load your CSV file
file_path = 'bdt_all_nowgt.csv'
data = pd.read_csv(file_path)

predicted = data['F :ANNZ_0']
#1:rounded and 0:no bulge
data['type'] = data['type'].replace({1: 1, 3: 0})
true_labels = data['type']
threshold = 0.5
binary_predictions = (predicted >= threshold).astype(int)

accuracy = accuracy_score(true_labels, binary_predictions)
precision = precision_score(true_labels, binary_predictions)
recall = recall_score(true_labels, binary_predictions)
f1_score = f1_score(true_labels, binary_predictions)
confusion_matrix=confusion_matrix(true_labels,binary_predictions)

print("Model Metrics:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"Confusion_Matrix:\n{confusion_matrix}")

#Statistics Calculation
from sklearn.metrics import confusion_matrix, mean_absolute_error
import numpy as np
tn, fp, fn, tp = confusion_matrix(true_labels,binary_predictions).ravel() #ravel() is something like .items() but this one is for dictionary : key,value
# ravel() makes it into 1d array and we can unpack
errors = [fp, fn]
positive=[tn,tp]
# Standard deviation 
std_dev = np.std(errors)
std_dev_p=np.std(positive)
# Mean absolute error
mae = mean_absolute_error(true_labels, binary_predictions)

print (f"tn:{tn}")
print(f"fp:{fp}")
print(f"fn:{fn}")
print(f"tp:{tp}")
print(f"Standard Deviation of Errors: {std_dev}")
print(f"Standard Deviation of Positives: {std_dev_p}")
print(f"Mean Absolute Error: {mae}")


#####################VISUALIZATION
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(8,8))
sns.kdeplot(data[true_labels == 1]['F :ANNZ_0'], color='blue', label='Rounded Galaxy (Class 1)', lw=3)##lw is line width
sns.kdeplot(data[true_labels == 0]['F :ANNZ_0'], color='red', label='No Bulge Galaxy (Class 0)', lw=3)
plt.axvline(x=0.5, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title(f'Distribution of Predictions using Gaussian KDE')
plt.xlabel('Predictions')
plt.ylabel('Density')
plt.legend()
plt.show()


#########OUTLINES
plt.figure(figsize=(8, 8))
plt.scatter(data.index[true_labels == 1], predicted[true_labels == 1], c='blue', alpha=0.5, s=25, linewidth=0.5, label='Rounded Galaxy : 1')
plt.scatter(data.index[true_labels == 0], predicted[true_labels == 0], c='red', alpha=0.5, s=25, linewidth=0.5, label='No Bulge Galaxy : 0')
plt.axhline(y=threshold, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title('Scatter Plot of Predicted Data Points')
plt.xlabel('Data Points Index')
plt.ylabel('Predictions')
plt.legend()
plt.show()
# Out:
# Model Metrics:
# Accuracy: 0.9019607843137255
# Precision: 0.9766355140186916
# Recall: 0.8931623931623932
# F1 Score: 0.9330357142857143
# Confusion_Matrix:
# [[ 67   5]
#  [ 25 209]]
# tn:67
# fp:5
# fn:25
# tp:209
# Standard Deviation of Errors: 10.0
# Standard Deviation of Positives: 71.0
# Mean Absolute Error: 0.09803921568627451

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,confusion_matrix

#This is where we put our csv file from the directory of 'bnnz/output/test_singleCls_quick/clasif/eval/ANNZ_singleCls_0000.csv'
#In this case i'm using jupyter notebook, so i will import the csv file into the same file where im doing this notebook
# Load your CSV file
file_path = 'hm_all_nowgt.csv'
data = pd.read_csv(file_path)

predicted = data['F :ANNZ_0']
#1:rounded and 0:no bulge
data['type'] = data['type'].replace({1: 1, 3: 0})
true_labels = data['type']
threshold = 0.5
binary_predictions = (predicted >= threshold).astype(int)

accuracy = accuracy_score(true_labels, binary_predictions)
precision = precision_score(true_labels, binary_predictions)
recall = recall_score(true_labels, binary_predictions)
f1_score = f1_score(true_labels, binary_predictions)
confusion_matrix=confusion_matrix(true_labels,binary_predictions)

print("Model Metrics:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"Confusion_Matrix:\n{confusion_matrix}")

#Statistics Calculation
from sklearn.metrics import confusion_matrix, mean_absolute_error
import numpy as np
tn, fp, fn, tp = confusion_matrix(true_labels,binary_predictions).ravel() #ravel() is something like .items() but this one is for dictionary : key,value
# ravel() makes it into 1d array and we can unpack
errors = [fp, fn]
positive=[tn,tp]
# Standard deviation 
std_dev = np.std(errors)
std_dev_p=np.std(positive)
# Mean absolute error
mae = mean_absolute_error(true_labels, binary_predictions)

print (f"tn:{tn}")
print(f"fp:{fp}")
print(f"fn:{fn}")
print(f"tp:{tp}")
print(f"Standard Deviation of Errors: {std_dev}")
print(f"Standard Deviation of Positives: {std_dev_p}")
print(f"Mean Absolute Error: {mae}")


#####################VISUALIZATION
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(8,8))
sns.kdeplot(data[true_labels == 1]['F :ANNZ_0'], color='blue', label='Rounded Galaxy (Class 1)', lw=3)##lw is line width
sns.kdeplot(data[true_labels == 0]['F :ANNZ_0'], color='red', label='No Bulge Galaxy (Class 0)', lw=3)
plt.axvline(x=0.5, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title(f'Distribution of Predictions using Gaussian KDE')
plt.xlabel('Predictions')
plt.ylabel('Density')
plt.legend()
plt.show()


#########OUTLINES
plt.figure(figsize=(8, 8))
plt.scatter(data.index[true_labels == 1], predicted[true_labels == 1], c='blue', alpha=0.5, s=25, linewidth=0.5, label='Rounded Galaxy : 1')
plt.scatter(data.index[true_labels == 0], predicted[true_labels == 0], c='red', alpha=0.5, s=25, linewidth=0.5, label='No Bulge Galaxy : 0')
plt.axhline(y=threshold, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title('Scatter Plot of Predicted Data Points')
plt.xlabel('Data Points Index')
plt.ylabel('Predictions')
plt.legend()
plt.show()
# Out:
# Model Metrics:
# Accuracy: 0.8856209150326797
# Precision: 0.9585253456221198
# Recall: 0.8888888888888888
# F1 Score: 0.9223946784922394
# Confusion_Matrix:
# [[ 63   9]
#  [ 26 208]]
# tn:63
# fp:9
# fn:26
# tp:208
# Standard Deviation of Errors: 8.5
# Standard Deviation of Positives: 72.5
# Mean Absolute Error: 0.11437908496732026

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,confusion_matrix

#This is where we put our csv file from the directory of 'bnnz/output/test_singleCls_quick/clasif/eval/ANNZ_singleCls_0000.csv'
#In this case i'm using jupyter notebook, so i will import the csv file into the same file where im doing this notebook
# Load your CSV file
file_path = 'fish_all_nowgt.csv'
data = pd.read_csv(file_path)

predicted = data['F :ANNZ_0']
#1:rounded and 0:no bulge
data['type'] = data['type'].replace({1: 1, 3: 0})
true_labels = data['type']
threshold = 0.5
binary_predictions = (predicted >= threshold).astype(int)

accuracy = accuracy_score(true_labels, binary_predictions)
precision = precision_score(true_labels, binary_predictions)
recall = recall_score(true_labels, binary_predictions)
f1_score = f1_score(true_labels, binary_predictions)
confusion_matrix=confusion_matrix(true_labels,binary_predictions)

print("Model Metrics:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"Confusion_Matrix:\n{confusion_matrix}")

#Statistics Calculation
from sklearn.metrics import confusion_matrix, mean_absolute_error
import numpy as np
tn, fp, fn, tp = confusion_matrix(true_labels,binary_predictions).ravel() #ravel() is something like .items() but this one is for dictionary : key,value
# ravel() makes it into 1d array and we can unpack
errors = [fp, fn]
positive=[tn,tp]
# Standard deviation 
std_dev = np.std(errors)
std_dev_p=np.std(positive)
# Mean absolute error
mae = mean_absolute_error(true_labels, binary_predictions)

print (f"tn:{tn}")
print(f"fp:{fp}")
print(f"fn:{fn}")
print(f"tp:{tp}")
print(f"Standard Deviation of Errors: {std_dev}")
print(f"Standard Deviation of Positives: {std_dev_p}")
print(f"Mean Absolute Error: {mae}")


#####################VISUALIZATION
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(8,8))
sns.kdeplot(data[true_labels == 1]['F :ANNZ_0'], color='blue', label='Rounded Galaxy (Class 1)', lw=3)##lw is line width
sns.kdeplot(data[true_labels == 0]['F :ANNZ_0'], color='red', label='No Bulge Galaxy (Class 0)', lw=3)
plt.axvline(x=0.5, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title(f'Distribution of Predictions using Gaussian KDE')
plt.xlabel('Predictions')
plt.ylabel('Density')
plt.legend()
plt.show()


#########OUTLINES
plt.figure(figsize=(8, 8))
plt.scatter(data.index[true_labels == 1], predicted[true_labels == 1], c='blue', alpha=0.5, s=25, linewidth=0.5, label='Rounded Galaxy : 1')
plt.scatter(data.index[true_labels == 0], predicted[true_labels == 0], c='red', alpha=0.5, s=25, linewidth=0.5, label='No Bulge Galaxy : 0')
plt.axhline(y=threshold, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title('Scatter Plot of Predicted Data Points')
plt.xlabel('Data Points Index')
plt.ylabel('Predictions')
plt.legend()
plt.show()
# Out:
# Model Metrics:
# Accuracy: 0.9052287581699346
# Precision: 0.9951690821256038
# Recall: 0.8803418803418803
# F1 Score: 0.9342403628117913
# Confusion_Matrix:
# [[ 71   1]
#  [ 28 206]]
# tn:71
# fp:1
# fn:28
# tp:206
# Standard Deviation of Errors: 13.5
# Standard Deviation of Positives: 67.5
# Mean Absolute Error: 0.09477124183006536

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,confusion_matrix

#This is where we put our csv file from the directory of 'bnnz/output/test_singleCls_quick/clasif/eval/ANNZ_singleCls_0000.csv'
#In this case i'm using jupyter notebook, so i will import the csv file into the same file where im doing this notebook
# Load your CSV file
file_path = 'maha_all_nowgt.csv'
data = pd.read_csv(file_path)

predicted = data['F :ANNZ_0']
#1:rounded and 0:no bulge
data['type'] = data['type'].replace({1: 1, 3: 0})
true_labels = data['type']
threshold = 0.5
binary_predictions = (predicted >= threshold).astype(int)

accuracy = accuracy_score(true_labels, binary_predictions)
precision = precision_score(true_labels, binary_predictions)
recall = recall_score(true_labels, binary_predictions)
f1_score = f1_score(true_labels, binary_predictions)
confusion_matrix=confusion_matrix(true_labels,binary_predictions)

print("Model Metrics:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"Confusion_Matrix:\n{confusion_matrix}")

#Statistics Calculation
from sklearn.metrics import confusion_matrix, mean_absolute_error
import numpy as np
tn, fp, fn, tp = confusion_matrix(true_labels,binary_predictions).ravel() #ravel() is something like .items() but this one is for dictionary : key,value
# ravel() makes it into 1d array and we can unpack
errors = [fp, fn]
positive=[tn,tp]
# Standard deviation 
std_dev = np.std(errors)
std_dev_p=np.std(positive)
# Mean absolute error
mae = mean_absolute_error(true_labels, binary_predictions)

print (f"tn:{tn}")
print(f"fp:{fp}")
print(f"fn:{fn}")
print(f"tp:{tp}")
print(f"Standard Deviation of Errors: {std_dev}")
print(f"Standard Deviation of Positives: {std_dev_p}")
print(f"Mean Absolute Error: {mae}")


#####################VISUALIZATION
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(8,8))
sns.kdeplot(data[true_labels == 1]['F :ANNZ_0'], color='blue', label='Rounded Galaxy (Class 1)', lw=3)##lw is line width
sns.kdeplot(data[true_labels == 0]['F :ANNZ_0'], color='red', label='No Bulge Galaxy (Class 0)', lw=3)
plt.axvline(x=0.5, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title(f'Distribution of Predictions using Gaussian KDE')
plt.xlabel('Predictions')
plt.ylabel('Density')
plt.legend()
plt.show()


#########OUTLINES
plt.figure(figsize=(8, 8))
plt.scatter(data.index[true_labels == 1], predicted[true_labels == 1], c='blue', alpha=0.5, s=25, linewidth=0.5, label='Rounded Galaxy : 1')
plt.scatter(data.index[true_labels == 0], predicted[true_labels == 0], c='red', alpha=0.5, s=25, linewidth=0.5, label='No Bulge Galaxy : 0')
plt.axhline(y=threshold, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title('Scatter Plot of Predicted Data Points')
plt.xlabel('Data Points Index')
plt.ylabel('Predictions')
plt.legend()
plt.show()
# Out:
# Model Metrics:
# Accuracy: 0.9052287581699346
# Precision: 0.9951690821256038
# Recall: 0.8803418803418803
# F1 Score: 0.9342403628117913
# Confusion_Matrix:
# [[ 71   1]
#  [ 28 206]]
# tn:71
# fp:1
# fn:28
# tp:206
# Standard Deviation of Errors: 13.5
# Standard Deviation of Positives: 67.5
# Mean Absolute Error: 0.09477124183006536

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,confusion_matrix

#This is where we put our csv file from the directory of 'bnnz/output/test_singleCls_quick/clasif/eval/ANNZ_singleCls_0000.csv'
#In this case i'm using jupyter notebook, so i will import the csv file into the same file where im doing this notebook
# Load your CSV file
file_path = 'ld_all_nowgt.csv'
data = pd.read_csv(file_path)

predicted = data['F :ANNZ_0']
#1:rounded and 0:no bulge
data['type'] = data['type'].replace({1: 1, 3: 0})
true_labels = data['type']
threshold = 0.5
binary_predictions = (predicted >= threshold).astype(int)

accuracy = accuracy_score(true_labels, binary_predictions)
precision = precision_score(true_labels, binary_predictions)
recall = recall_score(true_labels, binary_predictions)
f1_score = f1_score(true_labels, binary_predictions)
confusion_matrix=confusion_matrix(true_labels,binary_predictions)

print("Model Metrics:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"Confusion_Matrix:\n{confusion_matrix}")

#Statistics Calculation
from sklearn.metrics import confusion_matrix, mean_absolute_error
import numpy as np
tn, fp, fn, tp = confusion_matrix(true_labels,binary_predictions).ravel() #ravel() is something like .items() but this one is for dictionary : key,value
# ravel() makes it into 1d array and we can unpack
errors = [fp, fn]
positive=[tn,tp]
# Standard deviation 
std_dev = np.std(errors)
std_dev_p=np.std(positive)
# Mean absolute error
mae = mean_absolute_error(true_labels, binary_predictions)

print (f"tn:{tn}")
print(f"fp:{fp}")
print(f"fn:{fn}")
print(f"tp:{tp}")
print(f"Standard Deviation of Errors: {std_dev}")
print(f"Standard Deviation of Positives: {std_dev_p}")
print(f"Mean Absolute Error: {mae}")


#####################VISUALIZATION
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(8,8))
sns.kdeplot(data[true_labels == 1]['F :ANNZ_0'], color='blue', label='Rounded Galaxy (Class 1)', lw=3)##lw is line width
sns.kdeplot(data[true_labels == 0]['F :ANNZ_0'], color='red', label='No Bulge Galaxy (Class 0)', lw=3)
plt.axvline(x=0.5, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title(f'Distribution of Predictions using Gaussian KDE')
plt.xlabel('Predictions')
plt.ylabel('Density')
plt.legend()
plt.show()


#########OUTLINES
plt.figure(figsize=(8, 8))
plt.scatter(data.index[true_labels == 1], predicted[true_labels == 1], c='blue', alpha=0.5, s=25, linewidth=0.5, label='Rounded Galaxy : 1')
plt.scatter(data.index[true_labels == 0], predicted[true_labels == 0], c='red', alpha=0.5, s=25, linewidth=0.5, label='No Bulge Galaxy : 0')
plt.axhline(y=threshold, color='green', linestyle='--', label='Decision Threshold (0.5)')
plt.title('Scatter Plot of Predicted Data Points')
plt.xlabel('Data Points Index')
plt.ylabel('Predictions')
plt.legend()
plt.show()
# Out:
# Model Metrics:
# Accuracy: 0.9052287581699346
# Precision: 0.9951690821256038
# Recall: 0.8803418803418803
# F1 Score: 0.9342403628117913
# Confusion_Matrix:
# [[ 71   1]
#  [ 28 206]]
# tn:71
# fp:1
# fn:28
# tp:206
# Standard Deviation of Errors: 13.5
# Standard Deviation of Positives: 67.5
# Mean Absolute Error: 0.09477124183006536
